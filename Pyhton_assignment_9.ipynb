# %% [markdown]
# ### 1. Write a Python program to find words which are greater than given length k?

# %%
def wordsBiggerThanLenghtK(k,str):
    txt = str.split()
    listOfWords = []
    for i in txt:
        if len(i) > k:
            listOfWords.append(i)
    return listOfWords

str = input("Enter the string : ")
k = int(input("Enter the lenth K : "))

listword = wordsBiggerThanLenghtK(k,str)

print("\nThe original string ' {} '".format(str))

print("Words which are greater than length {}".format(k))
print(listword)
# Out:
# Enter the string :  My name is shweta
# Enter the lenth K :  4
# The original string ' My name is shweta '
# Words which are greater than length 4
# ['shweta']

# %% [markdown]
# ### 2. Write a Python program for removing i-th character from a string?

# %%
# Removes character at index i
def remove(str, i): 
  
    for j in range(len(str)):
        if j == i:
            str = str.replace(str[i], "", 1)
    return str      

str = input("Enter the string : ")
i = int(input("Enter the index : "))      

# Print the new string

print("The new string : ", remove(str, i))
# Out:
# Enter the string :  universitycollegedublin
# Enter the index :  2
# The new string :  unversitycollegedublin

# %% [markdown]
# ### 3. Write a Python program to split and join a string?

# %%
str = "this is a string"
str = str.split(" ") # str is converted to a list of strings. 
print("Spliting a string : ",str)


str2 = "-".join(str)
print("Joining a string : ",str2)
# Out:
# Spliting a string :  ['this', 'is', 'a', 'string']
# Joining a string :  this-is-a-string

# %% [markdown]
# ### 4. Write a Python to check if a given string is binary string or not?

# %%
def checkBinary(str):
    binary = '01'
    for i in range(len(str)):
        if str[i] not in binary:
            print('Not Binary')
            break
    else:
        print('Its a Binary')
        
str = input("Enter the string : ")
checkBinary(str)
# Out:
# Enter the string :  shweta
# Not Binary

# %% [markdown]
# ### 5. Write a Python program to find uncommon words from two Strings?

# %%
def unCommon(a,b):
    list_a = a.split()
    list_b = b.split()
    unCom =''
    
    for i in list_a:
        if i not in list_b:
            unCom = unCom +" "+ i
    for j in list_b:
        if j not in list_a:
            unCom = unCom +" "+ j
    return unCom

a = input("Enter the string a : ").lower()
b = input("Enter the string b : ").lower()

print("The list of un Common words : ", unCommon(a,b))
# Out:
# Enter the string a :  I like to work hard
# Enter the string b :  Consistency is vey important when you want to achieve something
# The list of un Common words :   i like work hard consistency is vey important when you want achieve something

# %% [markdown]
# ### 6. Write a Python to find all duplicate characters in string?

# %%
str = input("Enter the string a : ").lower()
duplicate = []

for i in str:
    if str.count(i) > 1 :
        if i not in duplicate:
            duplicate.append(i)
        
duplicate
# Out:
# Enter the string a :  A hard working girl
# ['a', ' ', 'r', 'i', 'g']

# %% [markdown]
# ### 7. Write a Python Program to check if a string contains any special character?

# %%
import string

string_char = string.punctuation
spChar = []

str = input("Enter the string a : ").lower()
for i in str:
    if i in string_char:
        spChar.append(i)
if len(spChar) > 0:
    print("String {} has special charecter/s : {}".format(str,spChar))
# Out:
# Enter the string a :  16@28#ucd
# String 16@28#ucd has special charecter/s : ['@', '#']
